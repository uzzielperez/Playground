# %%
import ROOT
from ROOT import TCanvas, TPad, TFile, TPaveText, TColor, TGaxis, TH1F, TPad, TH1D, TLegend
from ROOT import kBlack, kBlue, kRed
from ROOT import gBenchmark, gStyle, gROOT, gDirectory
# Out:
# Welcome to JupyROOT 6.08/07

# %%
path = "/uscms_data/d3/cuperez/CMSSW_8_0_25/src/scripts/macros/DiphotonAnalysis/"
filename = "diphoton16bkg_histograms.root"

# %%
f = ROOT.TFile.Open(path+filename)
f.ls()
# Out:
# TFile**		/uscms_data/d3/cuperez/CMSSW_8_0_25/src/scripts/macros/DiphotonAnalysis/diphoton16bkg_histograms.root
#  TFile*		/uscms_data/d3/cuperez/CMSSW_8_0_25/src/scripts/macros/DiphotonAnalysis/diphoton16bkg_histograms.root
#   KEY: TH1D	diphotonMinv;1
#   KEY: TH1D	photon1Pt;1
#   KEY: TH1D	photon1Eta;1
#   KEY: TH1D	photon1Phi;1
#   KEY: TH1D	photon2Pt;1
#   KEY: TH1D	photon2Eta;1
#   KEY: TH1D	photonPhi;1

# %%
# %jsroot on
c1=ROOT.TCanvas("mycanvas","mycanvas",600,600)
#c1.SetGrid( )

diphoton_Minv = f.Get("diphotonMinv")
diphoton_Minv.GetXaxis().SetTitleOffset(1.4)
diphoton_Minv.GetXaxis().SetTitle(r"m_{#gamma#gamma} scale[0.8]{(GeV)}")
diphoton_Minv.GetYaxis().SetTitleOffset(1.4)
diphoton_Minv.GetYaxis().SetTitle("weighted events/ 80 GeV")
diphoton_Minv.SetAxisRange(200, 1600) #To draw hist from 200 1600
diphoton_Minv.Draw("hist") #have to add hist to not draw with error bars

leg1 = TLegend(.60, 0.75, .97, .85)
leg1.SetBorderSize(0)
leg1.SetFillColor(0)
leg1.SetFillStyle(0)
leg1.SetTextFont(42)
leg1.SetTextSize(0.035)
leg1.AddEntry(diphoton_Minv,"SM Diphoton","l")
leg1.Draw()

#diphoton_Minv.SetLineStyle(1) #Default

c1.SetLogy()
#c1.SetFillStyle(3001)
#c1.SetFillColor(kRed)
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: mycanvas
# <div id="root_plot_13"
#      style="width: 596px; height: 572px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":22.4999867752186,"fY1":-2.38969909306613,"fX2":1797.50001322478,"fY2":3.27009809423668,"fXtoAbsPixelk":-7.55487502434132,"fXtoPixelk":-7.55487502434132,"fXtoPixel":0.335774642883892,"fYtoAbsPixelk":330.488236767479,"fYtoPixelk":330.488236767479,"fYtoPixel":-101.063692049465,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":22.4999867752186,"fPixeltoXk":22.4999867752186,"fPixeltoX":2.97818796384155,"fAbsPixeltoYk":3.27009809423668,"fPixeltoYk":-2.38969909306613,"fPixeltoY":-0.00989475032745246,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":200,"fUymin":-1.82371934060083,"fUxmax":1620,"fUymax":2.70411834177138,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":200,"fY1":-1.82371934060083,"fX2":1620,"fY2":2.70411834177138,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":50331656,"fName":"diphotonMinv","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":82,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50333704,"fName":"xaxis","fTitle":"m_{#gamma#gamma} scale[0.8]{(GeV)}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":80,"fXmin":0,"fXmax":1600,"fXbins":[],"fFirst":11,"fLast":81,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331656,"fName":"yaxis","fTitle":"weighted events\/ 80 GeV","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":5747676,"fTsumw":4374.87229943423,"fTsumw2":35.630470277321,"fTsumwx":787322.254832104,"fTsumwx2":178229413.631241,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[28.607782290163,0.00931137726751286,0.0268759643477978,0.069180964808679,0.211372313216692,0.680286878962035,9.03255341879434,9.00130252980568,6.63788179086499,4.69434552460942,3.09872913219158,0.617114617521176,0.379466957081202,0.27654446610841,0.2074433650923,0.156370362370023,0.118947596352653,0.0924600522513021,0.071964162885334,0.0574227606453901,0.046717 ...

# %%
# To draw all canvases 
#%jsroot on
#from ROOT import gROOT 
#gROOT.GetListOfCanvases().Draw()

# %%
filename2="diphoton2016bkg_histograms.root"
f2 = ROOT.TFile.Open(path+filename2)
#f2.ls()

# %%
# %jsroot on
c=ROOT.TCanvas("canvas","mycanvas",600,600)
diphoton_Minvn = f2.Get("diphotonMinvn")
diphoton_Minvn.GetXaxis().SetTitleOffset(1.4)
diphoton_Minvn.GetXaxis().SetTitle(r"m_{#gamma#gamma} scale[0.8]{(GeV)}")
diphoton_Minvn.GetYaxis().SetTitleOffset(1.4)
diphoton_Minvn.GetYaxis().SetTitle("weighted events/ 80 GeV")
diphoton_Minvn.SetAxisRange(200, 2000) #To draw hist from 200 1600
diphoton_Minvn.Draw("hist") #have to add hist to not draw with error bars

legend1 = TLegend(.60, 0.75, .97, .85)
legend1.SetBorderSize(0)
legend1.SetFillColor(0)
legend1.SetFillStyle(0)
legend1.SetTextFont(42)
legend1.SetTextSize(0.035)
legend1.AddEntry(diphoton_Minvn,"SM Diphoton","l")
legend1.Draw()


c.SetLogy()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# <div id="root_plot_20"
#      style="width: 596px; height: 572px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":22.4999867752186,"fY1":-2.38969909306613,"fX2":1797.50001322478,"fY2":3.27009809423668,"fXtoAbsPixelk":-7.55487502434132,"fXtoPixelk":-7.55487502434132,"fXtoPixel":0.335774642883892,"fYtoAbsPixelk":330.488236767479,"fYtoPixelk":330.488236767479,"fYtoPixel":-101.063692049465,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":22.4999867752186,"fPixeltoXk":22.4999867752186,"fPixeltoX":2.97818796384155,"fAbsPixeltoYk":3.27009809423668,"fPixeltoYk":-2.38969909306613,"fPixeltoY":-0.00989475032745246,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":200,"fUymin":-1.82371934060083,"fUxmax":1620,"fUymax":2.70411834177138,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":200,"fY1":-1.82371934060083,"fX2":1620,"fY2":2.70411834177138,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":50331656,"fName":"diphotonMinvn","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":82,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50333704,"fName":"xaxis","fTitle":"m_{#gamma#gamma} scale[0.8]{(GeV)}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":80,"fXmin":0,"fXmax":1600,"fXbins":[],"fFirst":11,"fLast":81,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331656,"fName":"yaxis","fTitle":"weighted events\/ 80 GeV","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":5747676,"fTsumw":4374.87229943423,"fTsumw2":35.630470277321,"fTsumwx":787322.254832104,"fTsumwx2":178229413.631241,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[28.607782290163,0.00931137726751286,0.0268759643477978,0.069180964808679,0.211372313216692,0.680286878962035,9.03255341879434,9.00130252980568,6.63788179086499,4.69434552460942,3.09872913219158,0.617114617521176,0.379466957081202,0.27654446610841,0.2074433650923,0.156370362370023,0.118947596352653,0.0924600522513021,0.071964162885334,0.0574227606453901,0.04671 ...

# %%
canvas = ROOT.TCanvas()
canvas.Clear()


hphoton1pTn = f2.Get("photon1Ptn")
hphoton2pTn = f2.Get("photon2Ptn")

hphoton1pTn.GetXaxis().SetTitleOffset(1.4)
hphoton1pTn.GetXaxis().SetTitle(r"p_{T} (GeV)")
hphoton1pTn.SetAxisRange(200, 2000)
hphoton1pTn.GetYaxis().SetTitleOffset(1)
hphoton1pTn.GetYaxis().SetTitle("weighted events/ 80 GeV")

hphoton1pTn.Draw("hist")
hphoton2pTn.SetLineColor(kBlack)
hphoton2pTn.Draw("hist same")


#diphoton_Minvn.GetXaxis().SetTitleOffset(1.4)
#diphoton_Minvn.GetXaxis().SetTitle(r"m_{#gamma#gamma} scale[0.8]{(GeV)}")
#diphoton_Minvn.GetYaxis().SetTitleOffset(1.4)
#diphoton_Minvn.GetYaxis().SetTitle("weighted events/ 80 GeV")
#diphoton_Minvn.SetAxisRange(200, 2000) #To draw hist from 200 1600

#leg = TLegend(.73,0.32,.97,.53)
leg = TLegend(.75, 0.75, .97, .85)
leg.SetBorderSize(0)
leg.SetFillColor(0)
leg.SetFillStyle(0)
leg.SetTextFont(42)
leg.SetTextSize(0.035)
leg.AddEntry(hphoton1pTn,r"#gamma_{1} p_{T}")
leg.AddEntry(hphoton2pTn,r"#gamma_{2} p_{T}")
leg.Draw()

canvas.SetLogy()
canvas.Draw()

#canvas.cd(1); diphoton_Minvn.Draw("hist")
#canvas.cd(2); diphoton_Minvn.Draw("hist")
#canvas.cd(3); diphoton_Minvn.Draw("hist")
#canvas.cd(3); diphoton_Minvn.Draw("hist")
# Out:
# <div id="root_plot_3"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":22.4999867752186,"fY1":-4.35372653618928,"fX2":1797.50001322478,"fY2":2.66031633715311,"fXtoAbsPixelk":-8.82247989419725,"fXtoPixelk":-8.82247989419725,"fXtoPixel":0.392112670213404,"fYtoAbsPixelk":179.022239315177,"fYtoPixelk":179.022239315177,"fYtoPixel":-67.2935721271231,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":22.4999867752186,"fPixeltoXk":22.4999867752186,"fPixeltoX":2.55028739432408,"fAbsPixeltoYk":2.66031633715311,"fPixeltoYk":-4.35372653618928,"fPixeltoY":-0.0148602603248779,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":200,"fUymin":-3.65232220704809,"fUxmax":1620,"fUymax":1.95891200801191,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":200,"fY1":-3.65232220704809,"fX2":1620,"fY2":1.95891200801191,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":50331656,"fName":"photon1Ptn","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":82,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50333704,"fName":"xaxis","fTitle":"p_{T} (GeV)","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":80,"fXmin":0,"fXmax":1600,"fXbins":[],"fFirst":11,"fLast":81,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331656,"fName":"yaxis","fTitle":"weighted events\/ 80 GeV","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":5747676,"fTsumw":4375.30522799946,"fTsumw2":35.6304848364747,"fTsumwx":414804.795756261,"fTsumwx2":50313019.7004079,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[28.607782290163,6.76586700681309e-4,0.0237287373952952,9.06484875219841,15.5253158364177,6.76817999421937,2.34593945017959,0.935701872278908,0.437805973852222,0.224489234335623,0.124330427782468,0.0696976154853657,0.0420789926326192,0.0234092163710494,0.013840252347634,0.00872343488135402,0.00613474512532101,0.00410421863098138,0.0028143561222683,0.00241288935827798,0.00160224716622696,0 ...

# %%
mcanvas = ROOT.TCanvas()
mcanvas.Clear()
mcanvas.Divide(2,1)

hphoton1etan = f2.Get("photon1Etan")
hphoton1phin = f2.Get("photon1Phin")
hphoton2etan = f2.Get("photon2Etan")
hphoton2phin = f2.Get("photon2Phin")

mcanvas.cd(1)

hphoton1pTn.GetXaxis().SetTitleOffset(1.4)
hphoton1pTn.GetXaxis().SetTitle(r"p_{T} (GeV)")
hphoton1pTn.SetAxisRange(200, 2000)
hphoton1pTn.GetYaxis().SetTitleOffset(1)
hphoton1pTn.GetYaxis().SetTitle("weighted events/ 80 GeV")

hphoton1etan.Draw("hist")
hphoton2etan.SetLineColor(kBlack)
hphoton2etan.Draw("hist same")

leg2 = TLegend(.68, 0.75, .97, .85)
leg2.SetBorderSize(0)
leg2.SetFillColor(0)
leg2.SetFillStyle(0)
leg2.SetTextFont(42)
leg2.SetTextSize(0.035)
leg2.AddEntry(hphoton1etan,r"#gamma_{1} p_{T}")
leg2.AddEntry(hphoton2etan,r"#gamma_{2} p_{T}")
leg2.Draw()

mcanvas.cd(2)
hphoton1phin.Draw("hist")
hphoton2phin.SetLineColor(kBlack)
hphoton2phin.Draw("hist same")

leg3 = TLegend(.68, 0.75, .97, .85)
leg3.SetBorderSize(0)
leg3.SetFillColor(0)
leg3.SetFillStyle(0)
leg3.SetTextFont(42)
leg3.SetTextSize(0.035)
leg3.AddEntry(hphoton1phin,r"#gamma_{1}")
leg3.AddEntry(hphoton2phin,r"#gamma_{2}")
leg3.Draw()

mcanvas.Draw()
# Out:
# <div id="root_plot_16"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":696,"fYtoAbsPixelk":472.00005,"fYtoPixelk":472.00005,"fYtoPixel":-472,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.0014367816091954,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00211864406779661,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-3.75000005587936,"fY1":-12.1112559381181,"fX2":3.75000005587936,"fY2":109.001296224192,"fXtoAbsPixelk":174.00005,"fXtoPixelk":167.040050155568,"fXtoPixel":44.5439993777275,"fYtoAbsPixelk":421.024047327328,"fYtoPixelk":416.304047432828,"fYtoPixel":-3.81925731026703,"fUtoAbsPixelk":6.96004984443188,"fUtoPixelk":5e-5,"fUtoPixel":334.080000311136,"fVtoAbsPixelk":467.2800501055,"fVtoPixelk":462.560000211,"fVtoPixel":-462.560000211,"fAbsPixeltoXk":-3.90625005456969,"fPixeltoXk":-3.75000005587936,"fPixeltoX":0.022449712957297,"fAbsPixeltoYk":110.237138565008,"fPixeltoYk":-12.1112559381181,"fPixeltoY":-0.26183101026259,"fXlowNDC":0.00999999977648258,"fYlowNDC":0.00999999977648258,"fXUpNDC":-2.35343736826454e-185,"fYUpNDC":-2.35343736826454e-185,"fWNDC":0.480000000447035,"fHNDC":0.980000000447035,"fAbsXlowNDC":0.00999999977648258,"fAbsYlowNDC":0.00999999977648258,"fAbsWNDC":0.480000000447035,"fAbsHNDC":0.980000000447035,"fUxmin":-3,"fUymin":0,"fUxmax":3,"fUymax":96.890040286074,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":1,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-3,"fY1":0,"fX2":3,"fY2":96.890040286074,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":50331656,"fName":"photon1Etan","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":82,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":80,"fXmin":-3,"fXmax":3,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null} ...
